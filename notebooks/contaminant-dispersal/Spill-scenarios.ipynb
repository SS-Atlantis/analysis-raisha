# %% [markdown]
# ## Parcels Lagrangian-tracking output
# Point pollution oil spill scenarios

# %%
from pathlib import Path
from parcels import plotTrajectoriesFile

# %% [markdown]
# #### Turn Point Dilbit spill seasonal trajectories

# %%
results = Path('results/')
summer_paths = sorted([p for p in results.glob('5b_TurnPoint_Dilbit_*-07-*OP_D50_wp3.zarr')])
for file in summer_paths:
    print(str(file))
    plotTrajectoriesFile(file)
# Out:
# results/5b_TurnPoint_Dilbit_2019-07-03_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2019-07-10_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-07-05_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-07-14_10000_OP_D50_wp3.zarr

# %%
results = Path('results/')
fall_paths = sorted([p for p in results.glob('5b_TurnPoint_Dilbit_*-10-*OP_D50_wp3.zarr')])
for file in fall_paths:
    print(str(file))
    plotTrajectoriesFile(file)
# Out:
# results/5b_TurnPoint_Dilbit_2019-10-13_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2019-10-20_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-10-20_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-10-29_10000_OP_D50_wp3.zarr

# %%
results = Path('results/')
winter_paths = sorted([p for p in results.glob('5b_TurnPoint_Dilbit_*-01-*OP_D50_wp3.zarr')])
for file in winter_paths:
    print(str(file))
    plotTrajectoriesFile(file)
# Out:
# results/5b_TurnPoint_Dilbit_2019-01-20_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-01-11_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-01-24_10000_OP_D50_wp3.zarr

# %%
results = Path('results/')
spring_paths = sorted([p for p in results.glob('5b_TurnPoint_Dilbit_*-04-*OP_D50_wp3.zarr')])
for file in spring_paths:
    print(str(file))
    plotTrajectoriesFile(file)
# Out:
# results/5b_TurnPoint_Dilbit_2019-04-06_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2019-04-12_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-04-08_10000_OP_D50_wp3.zarr
# results/5b_TurnPoint_Dilbit_2020-04-11_10000_OP_D50_wp3.zarr
