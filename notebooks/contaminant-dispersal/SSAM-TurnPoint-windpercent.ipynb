# %% [markdown]
# Results of changing wind percentages (% of wind affecting surface particles, wp) in Parcels

# %%
import os
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_beach_time(parcelsFileName, ax, label):
    
    pfile = xr.open_dataset(str(parcelsFileName), decode_cf=True)

    beached = np.ma.filled(pfile.variables['beached'], np.nan)
    time = np.ma.filled(pfile.variables['time'], np.nan)

    beach_time = beached.sum(axis=0)
    t1 = (time[1,:] - time[1,0])/(3600000000000) #hours

    ax.plot(t1, beach_time, label=label)
    #ax.set_xlabel('hours')
    ax.set_ylabel('# beached particles')
    ax.legend();

def plot_particles_beached(parcelsFileName, ax):
    
    pfile = xr.open_dataset(str(parcelsFileName), decode_cf=True)

    beached = np.ma.filled(pfile.variables['beached'], np.nan)
    time = np.ma.filled(pfile.variables['time'], np.nan)

    beach_time = beached.sum(axis=0)
    particles_beached = np.diff(beach_time)

    t1 = (time[1,:] - time[1,0])/(3600000000000) #hours
    #t2 = (time[1,:] - time[1,0])/(3600000000000*24) #days
    t_hours = t1[0:len(particles_beached)]
    #t_days = t2[0:len(particles_beached)]

    ax.plot(t_hours, particles_beached)
    #ax.set_xlabel('hours')
    ax.set_ylabel('# beached particles');

# %%
fig, ax = plt.subplots(2,1, figsize = (9,7))
ax[0].set_title('total particles beached over time')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP_D500_wind.nc', ax[0], 'D500')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP_D55.nc', ax[0], 'D55')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP.nc', ax[0], 'original')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP_wp3.nc', ax[0], 'WP3')

ax[1].set_title('particles beached at each time step')
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP_D500_wind.nc', ax[1])
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP_D55.nc', ax[1])
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP.nc', ax[1])
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2018-01-01_OP_wp3.nc', ax[1])
ax[1].set_xlabel('hours');

# %%
fig, ax = plt.subplots(figsize = (9,3))
ax.set_title('total particles beached over time')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2019-01-06_OP.nc', ax, '2019 Jan 6')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2019-01-06_OP_wp3.nc', ax, '2019 Jan 6 WP3')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2019-01-06_OP_D50_wp3.nc', ax, '2019 Jan 6 D50 WP3')
#plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2019-01-13_OP.nc', ax, '2019 Jan 13')

# %%
fig, ax = plt.subplots(2,1, figsize = (9,7))
ax[0].set_title('total particles beached over time')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP.nc', ax[0], 'original')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP_original_wp3.nc', ax[0], 'original_wp3')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP_D50.nc', ax[0], 'D50')
plot_beach_time('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP_D50_wp3.nc', ax[0], 'D50_wp3')


ax[1].set_title('particles beached at each time step')
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP.nc', ax[1])
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP_original_wp3.nc', ax[1])
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP_D50.nc', ax[1])
plot_particles_beached('results/5b_Turn_Point_Diluted_bitumen2020-01-19_OP_D50_wp3.nc', ax[1])
ax[1].set_xlabel('hours')
# Out:
# Text(0.5, 0, 'hours')
